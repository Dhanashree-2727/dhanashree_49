# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanashree-2727/dhanashree_49/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def validate_password(password):
    if len(password) < 8:
        return False

    has_upper = len(list(filter(str.isupper, password))) >= 1
    has_lower = len(list(filter(str.islower, password))) >= 1
    has_digit = len(list(filter(str.isdigit, password))) >= 1

    return has_upper and has_lower and has_digit


# Input
password = input("Enter Password: ")

if validate_password(password):
    print("Valid Password")
else:
    print("Invalid Password")
# Out:
# Enter Password: Dhanu123
# Valid Password

# %%
from functools import reduce

numbers = [2, 3, 4, 5]

result = reduce(lambda x, y: x * y, numbers)

print("Multiplication =", result)
# Out:
# Multiplication = 120

# %%
from functools import reduce

def multiply_list(lst):
    return reduce(lambda x, y: x * y, lst)

numbers = [1, 2, 3, 4, 5]
print(multiply_list(numbers))
# Out:
# 120
